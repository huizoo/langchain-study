# %%
from langchain_ollama import ChatOllama 

llm = ChatOllama(model="llama3.2:1b")

# llm.invoke(0)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt_template = PromptTemplate(
    template="What is the capital of {country}? Return the name of the city only.",
    input_variables=["country"],
)

ai_message = llm.invoke(prompt_template.invoke({"country": "France"}))

print(ai_message)

output_parser = StrOutputParser()

answer = output_parser.invoke(llm.invoke(prompt_template.invoke({"country": "France"})))
# Out:
# content='Paris' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T12:07:28.618604Z', 'done': True, 'done_reason': 'stop', 'total_duration': 624632100, 'load_duration': 482110000, 'prompt_eval_count': 40, 'prompt_eval_duration': 102139400, 'eval_count': 2, 'eval_duration': 36159500, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'} id='lc_run--019daff0-33f7-7841-b58d-623da1f3878e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 2, 'total_tokens': 42}

# %%
capital_chain = prompt_template | llm | output_parser

# %%
capital_chain.invoke({"country": "France"})
# Out:
# 'Paris'

# %%
country_prompt = PromptTemplate(
    template="""Guess the name of the country in the {continent} based on the following information:
    {information}
    Return the name of the country only.
    """,
    input_variables=["information", "continent"],
)

country_chain = country_prompt | llm | output_parser
# country_chain.invoke({"information": "The country is very famous for its wine in Europe."})

# %%
from langchain_core.runnables import RunnablePassthrough

final_chain = {"information": RunnablePassthrough(), "continent": RunnablePassthrough()} | {"country": country_chain} | capital_chain

# %%
final_chain.invoke({
    "information": "This country is very famous for its wine in Europe.",
    "continent": "Europe"
})
# Out:
# 'Rome.'
