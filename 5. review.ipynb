# %%
from langchain_ollama import ChatOllama


llm = ChatOllama(model="llama3.2:1b", temperature=0)

# %%
# 음식 이름 찾기

from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

food_prompt = PromptTemplate(
    template="""What is one of the most popular food in {country}? Please return the name of the food only.""",
    input_variables=["country"],
)

food_chain = food_prompt | llm | StrOutputParser()

# %%
food_chain.invoke({"country": "South Korea"})
# Out:
# 'Bibimbap.'

# %%
from langchain_core.prompts import ChatPromptTemplate

recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', '''Provide the recipe of the food that the user wants.
Please return the recipe only as a numberd list'''),
    ('human', 'What is the recipe of {food}?'),]
)

recipe_chain = recipe_prompt | llm | StrOutputParser()

# %%
recipe_chain.invoke({'food': 'bibimbap'})
# Out:
# 'I can provide you with a traditional Korean recipe for Bibimbap. Here it is:\n\n**Ingredients:**\n\n* 1 cup of mixed vegetables (zucchini, carrots, bean sprouts, spinach)\n* 1/2 cup of cooked white rice\n* 1/4 cup of chopped cucumber\n* 1/4 cup of chopped carrot\n* 1/4 cup of chopped green onion\n* 1/4 cup of toasted sesame seeds\n* 2 tablespoons of Gochujang (Korean chili paste)\n* 2 tablespoons of soy sauce\n* 2 tablespoons of rice vinegar\n* 1 tablespoon of vegetable oil\n* 1 teaspoon of ground black pepper\n* 1/2 teaspoon of crushed red pepper flakes (optional)\n* 2 eggs, fried or poached\n* 1/4 cup of kimchi, chopped (optional)\n\n**Instructions:**\n\n1. Cook the mixed vegetables and set aside.\n2. Prepare the rice by cooking it according to package instructions.\n3. In a separate pan, heat the vegetable oil over medium heat. Add the Gochujang, soy sauce, rice vinegar, black pepper, and crushed red pepper flakes (if using). Stir until the sauce is well combined.\n4. To assemble the Bibimbap, place a scoop of cooked white rice in a bowl. Arrange the mixed vegetables on top of the rice.\n5. Place a fried or poached egg on top of the vegetables.\n6. Drizzle the Gochujang sauce over the egg and vegetables.\n7. Sprinkle toasted sesame seeds and chopped green onion over the top.\n8. Serve immediately, garnished with kimchi (if using).\n\n**Note:** Traditionally, Bibimbap is served with a variety of toppings, including meat (such as beef or pork), boiled eggs, and pickled daikon radish. Feel free to customize your dish to your liking!'

# %%
final_chain = {'food': food_chain} | recipe_chain

# %%
final_chain.invoke({'country': 'France'})
# Out:
# "Here's a classic recipe for croissants:\n\n**Ingredients:**\n\nFor the dough:\n\n1. 1 cup warm milk (105°F to 115°F)\n2. 1/4 cup granulated sugar\n3. 2 teaspoons active dry yeast\n4. 3 cups all-purpose flour\n5. 1 teaspoon salt\n6. 1/4 cup unsalted butter, melted\n\nFor the butter block:\n\n7. 1/2 cup (1 stick) unsalted butter, softened\n8. 1/4 cup granulated sugar\n\n**Instructions:**\n\n1. **Step 1: Make the dough**\n\t* In a small bowl, combine warm milk and sugar. Sprinkle yeast over the mixture and let it sit for 5-10 minutes, until frothy.\n\t* In a large mixing bowl, whisk together flour, salt, and melted butter.\n\t* Add the yeast mixture to the dry ingredients and mix until a shaggy dough forms.\n2. **Step 2: Knead the dough**\n\t* Turn the dough out onto a floured surface and knead for 10-12 minutes, until smooth and elastic.\n3. **Step 3: Rest the dough**\n\t* Place the dough in a lightly oiled bowl, cover with plastic wrap, and let it rise in a warm place for 1 hour, or until doubled in size.\n4. **Step 4: Prepare the butter block**\n\t* On a lightly floured surface, roll out the softened butter to a rectangle about 1/2-inch thick.\n5. **Step 5: Laminate the dough**\n\t* Roll out the risen dough to a large rectangle about 1/4-inch thick.\n\t* Place the butter block on top of the dough and fold it over, like a letter.\n\t* Rotate the dough 90° and roll it out again to a large rectangle about 1/4-inch thick.\n6. **Step 6: Repeat the folding process**\n\t* Roll out the dough for another 2-3 repetitions, folding and rotating it after each roll-out.\n7. **Step 7: Cut and shape the croissants**\n\t* After the final fold, roll out the dough to a large rectangle about 1/4-inch thick.\n\t* Use a pastry cutter or a sharp knife to cut the dough into long, thin triangles.\n\t* Roll each triangle into a croissant shape, curling the ends towards each other.\n8. **Step 8: Proof and bake**\n\t* Place the croissants on a parchment-lined baking sheet, leaving about 1 inch of space between each one.\n\t* Cover with plastic wrap and let them rise in a warm place for 1-2 hours, or until puffed and doubled in size.\n\t* Preheat oven to 400°F (200°C). Bake the croissants for 15-20 minutes, or until golden brown.\n\n**Note:** This is a classic recipe, but you can experiment with different flavors, such as chocolate or nuts, by adding them to the dough before rolling it out."
