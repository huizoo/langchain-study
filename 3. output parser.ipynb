# %%
from langchain_ollama import ChatOllama 

llm = ChatOllama(model="llama3.2:1b")

# llm.invoke(0)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt_template = PromptTemplate(
    template="What is the capital of {country}? Return the name of the city only.",
    input_variables=["country"],
)

ai_message = llm.invoke(prompt_template.invoke({"country": "France"}))

print(ai_message)

output_parser = StrOutputParser()

answer = output_parser.invoke(llm.invoke(prompt_template.invoke({"country": "France"})))
# Out:
# content='Paris' additional_kwargs={} response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T11:29:00.3187654Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4113313000, 'load_duration': 3980624800, 'prompt_eval_count': 40, 'prompt_eval_duration': 90879500, 'eval_count': 2, 'eval_duration': 33621000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'} id='lc_run--019dafcc-ed89-7100-9e39-f28d70f1f54f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 2, 'total_tokens': 42}

# %%
ai_message
# Out:
# AIMessage(content='Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T11:18:26.1655299Z', 'done': True, 'done_reason': 'stop', 'total_duration': 347129300, 'load_duration': 194991500, 'prompt_eval_count': 40, 'prompt_eval_duration': 91015700, 'eval_count': 3, 'eval_duration': 56028100, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019dafc3-4f19-7243-b0ba-1fb56a9ad473-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 3, 'total_tokens': 43})

# %%
answer
# Out:
# 'Paris'

# %%
from pydantic import BaseModel, Field

class CountryDetail(BaseModel):
    capital: str = Field(description="The capital of the country")
    population: int = Field(description="The population of the country")
    language: str = Field(description="The language of the country")
    currency: str = Field(description="The currency of the country")

structured_llm = llm.with_structured_output(CountryDetail)

# %%
from langchain_core.output_parsers import JsonOutputParser

country_detail_prompt = PromptTemplate(
    template="""Give following information about {country}:
    - Capital
    - Population
    - Language
    - Currency

    Return the answer in JSON format. And return only the JSON data without any other text.
    """,
    input_variables=["country"],
)

country_detail_prompt.invoke({"country": "France"})

# output_parser = JsonOutputParser()
json_ai_message = structured_llm.invoke(country_detail_prompt.invoke({"country": "France"}))
# output_parser.invoke()

# %%
json_ai_message.model_dump()
# Out:
# {'capital': 'Paris',
#  'population': 67,
#  'language': 'French',
#  'currency': 'Euro'}
