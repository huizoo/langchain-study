# %%
from langchain_ollama import ChatOllama 

llm = ChatOllama(model="llama3.2:1b")

# llm.invoke(0)

# %%
from langchain_core.prompts import PromptTemplate

prompt_template = PromptTemplate(
    template="What is the capital of {country}?",
    input_variables=["country"],
)

prompt = prompt_template.invoke({"country": "France"})

print(prompt)

llm.invoke(prompt)
# Out:
# text='What is the capital of France?'
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T10:31:58.6745389Z', 'done': True, 'done_reason': 'stop', 'total_duration': 740977600, 'load_duration': 427505100, 'prompt_eval_count': 32, 'prompt_eval_duration': 37906700, 'eval_count': 8, 'eval_duration': 256960600, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019daf98-c4ec-7a51-9f32-10a0663668b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40})

# %%
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# 답변 형식에 대한 예제
message_list = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="What is the capital of France?"),
    AIMessage(content="The capital of France is Paris."),
    HumanMessage(content="What is the capital of Germany?"),
    AIMessage(content="The capital of Germany is Berlin."),
    HumanMessage(content="What is the capital of {country}}?"),
]   

llm.invoke(message_list)
# Out:
# AIMessage(content="You're testing my knowledge of country capitals! I'll do my best to answer correctly.\n\nTo provide an accurate response, could you please specify which country you'd like to know the capital for?", additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T10:41:43.8587671Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1595933400, 'load_duration': 189997600, 'prompt_eval_count': 88, 'prompt_eval_duration': 93862700, 'eval_count': 40, 'eval_duration': 1240835700, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019dafa1-af75-7261-afcf-bcee0d2ab6c4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 88, 'output_tokens': 40, 'total_tokens': 128})

# %%
from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "What is the capital of {country}?"),
])

chat_prompt = chat_prompt_template.invoke({"country": "France"})

print(chat_prompt)
# Out:
# messages=[SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}), HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={})]

# %%
chat_prompt.messages
# Out:
# [SystemMessage(content='You are a helpful assistant.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='What is the capital of France?', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke(chat_prompt)
# Out:
# AIMessage(content='The capital of France is Paris.', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-04-21T10:43:05.9387322Z', 'done': True, 'done_reason': 'stop', 'total_duration': 620506600, 'load_duration': 332960300, 'prompt_eval_count': 38, 'prompt_eval_duration': 34547000, 'eval_count': 8, 'eval_duration': 237702900, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019dafa2-f3e4-7fb2-a440-3e9c2c618cc0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 38, 'output_tokens': 8, 'total_tokens': 46})
